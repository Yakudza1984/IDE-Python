# %%
import pandas as pd
melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
display(melb_df['Date'])
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
print(melb_df['Date'].dt.quarter.value_counts().index[1])
print(melb_df[melb_df['Date'].dt.quarter == 2].shape[0])
# Out:
# 2
# 4359

# %%
columns_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
for col in melb_df.columns:
    if col not in columns_to_exclude and melb_df[col].nunique()<150:
        melb_df[col] = melb_df[col].astype('category')
        
melb_df.select_dtypes(include="category")
# Out:
#              Suburb   Type Method   SellerG CouncilArea  \
# 0        Abbotsford  house      S    Biggin       Yarra
# 1        Abbotsford  house      S    Biggin       Yarra
# 2        Abbotsford  house     SP    Biggin       Yarra
# 3        Abbotsford  house     PI    Biggin       Yarra
# 4        Abbotsford  house     VB    Nelson       Yarra
# ...             ...    ...    ...       ...         ...
# 13575         other  house      S     Barry         NaN
# 13576  Williamstown  house     SP  Williams         NaN
# 13577  Williamstown  house      S     Raine         NaN
# 13578  Williamstown  house     PI   Sweeney         NaN
# 13579    Yarraville  house     SP   Village         NaN
#
#                        Regionname MonthSale WeekdaySale StreetType Weekend
# 0           Northern Metropolitan         3           5         St       1
# 1           Northern Metropolitan         4           5         St       1
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(
    by='AreaRatio',
    ascending=True,
    ignore_index=True
)

print(melb_df['BuildingArea'][1557])
# Out:
# 126.0

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
filtered_data = melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
    )
print(filtered_data.loc[18, 'Price'])
# Out:
# 1300000.0

# %%
melb_df.groupby('Rooms')['Price'].mean()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 7     1.920700e+06
# 8     1.602750e+06
# 10    9.000000e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std()
# Out:
# C:\Users\yermek.zhunuspekov\AppData\Local\Temp\ipykernel_24868\1377463709.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std()
# Regionname
# Eastern Metropolitan          0.047890
# Eastern Victoria              0.147067
# Northern Metropolitan         0.049639
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Southern Metropolitan         0.043080
# Western Metropolitan          0.051251
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %%
mask1 = melb_df['Date']>='2017-05-01'
mask2 = melb_df['Date']<='2017-09-01'
melb_df[mask1&mask2].groupby('SellerG')['Price'].sum()
# Out:
# C:\Users\yermek.zhunuspekov\AppData\Local\Temp\ipykernel_24868\3876910794.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[mask1&mask2].groupby('SellerG')['Price'].sum()
# SellerG
# Alexkarbon        10985000.0
# Barry            296723050.0
# Bells              8656000.0
# Biggin           110429500.0
# Brad              55955000.0
# Buckingham        19033000.0
# Burnham            4550500.0
# Buxton           219104000.0
# C21               19515000.0
# Cayzer             4439000.0
# Chisholm          23225000.0
# Collins           20217000.0
# Douglas           18341000.0
# Eview             19791500.0
# Fletchers        108847700.0
# Gary              39138400.0
# Greg              85621000.0
# HAR               25568000.0
# Harcourts         68720250.0
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    fill_value=0,
    aggfunc='median'
)
# Out:
# C:\Users\yermek.zhunuspekov\AppData\Local\Temp\ipykernel_24868\1653509808.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# Douglas         684000.0   500000.0  494500.0
# ...
